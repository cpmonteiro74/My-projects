# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
points=np.arange(-5,5,0.01)

# %%
dx,dy=np.meshgrid(points,points)

# %%
dx
# Out:
# array([[-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99],
#        [-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99],
#        [-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99],
#        ...,
#        [-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99],
#        [-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99],
#        [-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99]])

# %%
dy
# Out:
# array([[-5.  , -5.  , -5.  , ..., -5.  , -5.  , -5.  ],
#        [-4.99, -4.99, -4.99, ..., -4.99, -4.99, -4.99],
#        [-4.98, -4.98, -4.98, ..., -4.98, -4.98, -4.98],
#        ...,
#        [ 4.97,  4.97,  4.97, ...,  4.97,  4.97,  4.97],
#        [ 4.98,  4.98,  4.98, ...,  4.98,  4.98,  4.98],
#        [ 4.99,  4.99,  4.99, ...,  4.99,  4.99,  4.99]])

# %%
z = (np.sin(dx)*2 + np.cos(dy))

# %%
z
# Out:
# array([[ 2.20151073,  2.20708799,  2.21247291, ..., -1.65034058,
#         -1.64514854, -1.63976362],
#        [ 2.19190747,  2.19748473,  2.20286964, ..., -1.65994384,
#         -1.6547518 , -1.64936689],
#        [ 2.1822768 ,  2.18785405,  2.19323897, ..., -1.66957451,
#         -1.66438248, -1.65899756],
#        ...,
#        [ 2.17261968,  2.17819694,  2.18358186, ..., -1.67923163,
#         -1.67403959, -1.66865467],
#        [ 2.1822768 ,  2.18785405,  2.19323897, ..., -1.66957451,
#         -1.66438248, -1.65899756],
#        [ 2.19190747,  2.19748473,  2.20286964, ..., -1.65994384,
#         -1.6547518 , -1.64936689]])

# %%
plt.imshow(z)
plt.colorbar()

# %%
A=np.array([1,2,3,4])

# %%
B=np.array([100,200,300,400])

# %%
Condition=np.array([True,False,True,False])

# %%
Answer=np.where(Condition,A,B)

# %%
Answer
# Out:
# array([  1, 200,   3, 400])

# %%
Answer2 = [(a if c else b) for a,b,c in zip(A,B,Condition)]

# %%
Answer2
# Out:
# [1, 200, 3, 400]
